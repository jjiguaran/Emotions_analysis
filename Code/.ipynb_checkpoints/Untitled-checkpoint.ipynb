# %%
import pandas as pd
import json
from glob import glob
import os

# %%
tweets_df = pd.read_json('../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/00/29.json.bz2' , lines=True)
tweets_df
# Out:
#                     created_at            id        id_str  \
# 0    2021-08-01 06:29:00+00:00  1.421720e+18  1.421720e+18
# 1    2021-08-01 06:29:00+00:00  1.421720e+18  1.421720e+18
# 2    2021-08-01 06:29:00+00:00  1.421720e+18  1.421720e+18
# 3    2021-08-01 06:29:00+00:00  1.421720e+18  1.421720e+18
# 4    2021-08-01 06:29:00+00:00  1.421720e+18  1.421720e+18
# ...                        ...           ...           ...
# 2786                       NaT           NaN           NaN
# 2787                       NaT           NaN           NaN
# 2788                       NaT           NaN           NaN
# 2789                       NaT           NaN           NaN
# 2790                       NaT           NaN           NaN
#
#                                                    text  \
# 0     아아…. 당신이 '극한의 땅에서도 알몸으로~' 어쩌고 하며 비유한 의미를 잘 알겠어...
# 1           오... 나 란더노티카로 추천해주는 곳 가보고 싶음 이거 약간 쓸데없는 호기심
# 2     RT @Kvin_1: 내일이면 8월, 기쁘고 아름다운 일들만 기억되는 새 달이 되기...
# ...

# %%
place = pd.json_normalize(tweets_df['place'])

# %%
place.columns
# Out:
# Index(['id', 'url', 'place_type', 'name', 'full_name', 'country_code',
#        'country', 'bounding_box.type', 'bounding_box.coordinates'],
#       dtype='object')

# %%
tweets_df

# %%
tweets_df[place.columns] = place

# %%
tweets_df =tweets_df[tweets_df['country'].notnull()]

# %%
file_names = glob(os.path.join('../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/12/' "*.bz2"))

# %%
df_hold_list = []
for file in file_names:
    df_hold_list.append(pd.read_json(file, lines=True))

# %%
df = pd.concat(df_hold_list, axis=0)

# %%
place = pd.json_normalize(tweets_df['place'])

# %%
df[place.columns] = place

# %%
df =df[df['country'].notnull()]

# %%
df['country'].value_counts()
# Out:
# 日本               93
# United States    62
# Tanzania         31
# Nigeria          31
# South Africa     31
# Türkiye          31
# Pakistan         31
# Brasil           31
# Name: country, dtype: int64

# %%
subfolders = [ f.path for f in os.scandir('../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/') if f.is_dir() ]

# %%
df_hold_list = []
for i in subfolders:
# Out:
# ['../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/06',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/23',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/11',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/12',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/08',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/16',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/13',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/17',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/10',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/04',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/19',
#  '../Tesis de maestria/Data/archiveteam-twitter-stream-2021-08/2021/08/01/15',
# ...
